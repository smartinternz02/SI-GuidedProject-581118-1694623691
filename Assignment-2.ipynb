# %% [markdown]
# ## Assignment - 2
# ## Name : Vajjah Srinivasa Taaran
# ## Reg no : 21BCE8745

# %%
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('car_crashes')

# %%
df
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
df.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %%
df.tail()
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 46   12.7     2.413    3.429          11.049       11.176       768.95
# 47   10.6     4.452    3.498           8.692        9.116       890.03
# 48   23.8     8.092    6.664          23.086       20.706       992.61
# 49   13.8     4.968    4.554           5.382       11.592       670.31
# 50   17.4     7.308    5.568          14.094       15.660       791.14
#
#     ins_losses abbrev
# 46      153.72     VA
# 47      111.62     WA
# 48      152.56     WV
# 49      106.62     WI
# 50      122.04     WY

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   total           51 non-null     float64
#  1   speeding        51 non-null     float64
#  2   alcohol         51 non-null     float64
#  3   not_distracted  51 non-null     float64
#  4   no_previous     51 non-null     float64
#  5   ins_premium     51 non-null     float64
#  6   ins_losses      51 non-null     float64
#  7   abbrev          51 non-null     object
# dtypes: float64(7), object(1)
# memory usage: 3.3+ KB

# %%
df.shape
# Out:
# (51, 8)

# %%
sns.scatterplot(x="total" , y ="alcohol",data = df) 
print("Alcohol is directly proportional to total")
# Out:
# Alcohol is directly proportional to total

# %%
sns.scatterplot(x="speeding" , y ="total",data = df) 
print("Alcohol is directly proportional to total whereas speeding is inversely proportional to total")
# Out:
# Alcohol is directly proportional to total whereas speeding is inversely proportional to total

# %%
sns.lineplot(x="total" , y ="alcohol",data = df,errorbar= None)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
sns.histplot(df["speeding"])
print("Speeding vs Density distribution")
# Out:
# Speeding vs Density distribution

# %%
sns.relplot(x="speeding" , y ="alcohol",data =df,hue = "abbrev")

# %%
df["abbrev"].value_counts()
print("Here, we get count of all categories and has everything repeated")
# Out:
# Here, we get count of all categories and has everything repeated

# %%
sns.barplot(data = df,x = "speeding",y = "alcohol",errorbar = None) 
print("bargraph: speeding vs alcohol")
# Out:
# bargraph: speeding vs alcohol

# %%
sns.countplot(df["total"])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(data= df,x = "alcohol")
# Out:
# <Axes: xlabel='alcohol', ylabel='count'>

# %%
sns.jointplot(x="speeding" , y ="alcohol",data =df)

# %%
sns.boxplot(x="total" , y ="alcohol",data =df)
# Out:
# <Axes: xlabel='total', ylabel='alcohol'>

# %%
corr= df.corr() 
corr
# Out:
# /var/folders/0g/xqmh0yz92jx_s8ljsv3x08wr0000gn/T/ipykernel_36494/3864596578.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr= df.corr()
#                    total  speeding   alcohol  not_distracted  no_previous  \
# total           1.000000  0.611548  0.852613        0.827560     0.956179
# speeding        0.611548  1.000000  0.669719        0.588010     0.571976
# alcohol         0.852613  0.669719  1.000000        0.732816     0.783520
# not_distracted  0.827560  0.588010  0.732816        1.000000     0.747307
# no_previous     0.956179  0.571976  0.783520        0.747307     1.000000
# ins_premium    -0.199702 -0.077675 -0.170612       -0.174856    -0.156895
# ins_losses     -0.036011 -0.065928 -0.112547       -0.075970    -0.006359
#
#                 ins_premium  ins_losses
# ...

# %%
sns.heatmap(corr,annot= True)
# Out:
# <Axes: >

# %%
x=df["alcohol"]
y = df["speeding"]
plt.bar(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
plt.barh(x,y)
# Out:
# <BarContainer object of 51 artists>

# %%
plt.barh(x,y,color = 'green')
# Out:
# <BarContainer object of 51 artists>

# %%
plt.bar(x,y,width = 0.2)
# Out:
# <BarContainer object of 51 artists>

# %%
plt.hist(x)
# Out:
# (array([ 2.,  3., 13., 13., 11.,  2.,  4.,  0.,  0.,  3.]),
#  array([ 1.593 ,  2.4375,  3.282 ,  4.1265,  4.971 ,  5.8155,  6.66  ,
#          7.5045,  8.349 ,  9.1935, 10.038 ]),
#  <BarContainer object of 10 artists>)

# %%
x1 =(df["alcohol"])
fig = plt.figure()
axes1 = fig.add_axes([0.1,0.1,0.8,0.8]) 
axes1.pie(x1,y,autopct="%0.2f%%",colors=["red","green"])
# Out:
# ([<matplotlib.patches.Wedge at 0x14b223690>,
# ...
#  [Text(8.410699544034177, 0.5989634212398267, ''),
#   Text(8.352451213487306, 1.686416237562493, ''),
#   Text(7.219080145466262, 2.4076922256249467, ''),
#   Text(4.596307879757315, 2.282844251034401, ''),
#   Text(4.442676050348083, 2.8900916095625004, ''),
#   Text(4.8174064272344586, 3.7939450859020254, ''),
#   Text(4.381069891848448, 4.198434303730266, ''),
#   Text(4.654492093706887, 5.566438659468016, ''),
#   Text(1.7922050148895288, 2.5367769284280444, ''),
#   Text(2.4545111102703068, 4.193477817940573, ''),
#   Text(1.6384041636012552, 3.7191030903558016, ''),
#   Text(2.868396865351445, 10.15257599936302, ''),
#   Text(0.8499282227709963, 6.553112696737128, ''),
#   Text(0.1038203367441988, 5.7070557503565995, ''),
#   Text(-0.423145844593834, 4.706014512748869, ''),
#   Text(-0.7197898051735775, 3.699630202651095, ''),
#   Text(-1.7198394510077382, 5.650043208928353, ''),
# ...
